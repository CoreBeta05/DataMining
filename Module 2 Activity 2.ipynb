# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
import statistics
import seaborn as sns

# %%
#Numerical & Numerical
df = pd.read_csv('C:\\Users\\crew laptop\\Desktop\\CS 325 DATA MINING\\Datasets\\adults.csv')
print(df.head())
# Out:
#    age          workclass  fnlwgt   education  educational-num  \
# 0   39          State-gov   77516   Bachelors               13
# 1   50   Self-emp-not-inc   83311   Bachelors               13
# 2   38            Private  215646     HS-grad                9
# 3   53            Private  234721        11th                7
# 4   28            Private  338409   Bachelors               13
#
#         marital-status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %%
df.plot(
   x ='age', 
   y ='income', 
   kind='scatter', title="Scatter Plot"
)
plt.show()

# %%
#Linear Correlation
df.corr().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_48188_row0_col0, #T_48188_row1_col1, #T_48188_row2_col2, #T_48188_row3_col3, #T_48188_row4_col4, #T_48188_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_48188_row0_col1, #T_48188_row1_col0, #T_48188_row1_col2, #T_48188_row1_col5, #T_48188_row3_col4, #T_48188_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_48188_row0_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_48188_row0_col3, #T_48188_row2_col4, #T_48188_row5_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_48188_row0_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_48188_row0_col5, #T_48188_row5_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_48188_row1_col3, #T_48188_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_48188_row1_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_48188_row2_col0 {
#   background-color: #e3eef8;
# ...

# %%
df.cov().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_8c1bd_row0_col0, #T_8c1bd_row2_col0, #T_8c1bd_row4_col0, #T_8c1bd_row5_col0 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_8c1bd_row0_col1, #T_8c1bd_row0_col3, #T_8c1bd_row1_col0, #T_8c1bd_row1_col2, #T_8c1bd_row1_col4, #T_8c1bd_row1_col5, #T_8c1bd_row2_col1, #T_8c1bd_row2_col3, #T_8c1bd_row3_col1, #T_8c1bd_row4_col1, #T_8c1bd_row4_col3, #T_8c1bd_row5_col1, #T_8c1bd_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8c1bd_row0_col2, #T_8c1bd_row2_col2, #T_8c1bd_row5_col2 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_8c1bd_row0_col4, #T_8c1bd_row2_col4, #T_8c1bd_row5_col4 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_8c1bd_row0_col5, #T_8c1bd_row2_col5 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_8c1bd_row1_col1, #T_8c1bd_row3_col0, #T_8c1bd_row3_col2, #T_8c1bd_row3_col3, #T_8c1bd_row3_col5, #T_8c1bd_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
#variance
print(df['age'].var())
print(df['hours-per-week'].var())
# Out:
# 186.06140024879625
# 152.45899505042865

# %%
bl = pd.read_csv('C:\\Users\\crew laptop\\Desktop\\CS 325 DATA MINING\\Datasets\\adult2.csv')
df=pd.DataFrame.from_dict(bl);df
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %%
pd.crosstab(bl['gender'], bl['race']).plot(kind='bar', stacked=True)
plt.title("ADULT STACKED COLUMN CHART")
# Out:
# Text(0.5, 1.0, 'ADULT STACKED COLUMN CHART')

# %%
fig=plt.figure(figsize=(8,4))
ax1=plt.subplot(1,1,1)
ax1.bar(df.gender, df.race, color="Blue")
ax2=ax1.twinx()
ax2.plot(df.gender, df.race, "o-", color="Red", linewidth=1.5)
plt.show()

# %%
df = pd.read_csv('C:\\Users\\crew laptop\\Desktop\\CS 325 DATA MINING\\Datasets\\adult3.csv')
df=pd.DataFrame.from_dict(df);df
# Out:
#     age  gender
# 0    25    Male
# 1    38    Male
# 2    28    Male
# 3    44    Male
# 4    18  Female
# 5    34    Male
# 6    29    Male
# 7    63    Male
# 8    24  Female
# 9    55    Male
# 10   65    Male
# 11   36    Male
# 12   26  Female
# 13   58    Male
# 14   48    Male
# 15   43    Male
# 16   20    Male
# 17   43  Female
# 18   37  Female
# 19   40    Male
# 20   34    Male
# 21   34  Female
# 22   72  Female
# 23   25    Male

# %%
df.plot(figsize=(12, 8), 
        style=['^-'], 
        yerr=df,
        markersize=1)
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure(figsize=(8,4))
ax1=plt.subplot(1,1,1)
ax1.bar(df.gender, df.age, color="Blue")
ax2=ax1.twinx()
ax2.plot(df.gender, df.age, "o-", color="Red", linewidth=1.5)
plt.show()
